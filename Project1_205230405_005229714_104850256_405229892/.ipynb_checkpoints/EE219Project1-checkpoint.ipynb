# %% [markdown]
# # Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import random
from sklearn.datasets import fetch_20newsgroups #news group data set
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk import pos_tag
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import NMF
from sklearn.decomposition import TruncatedSVD
from sklearn.svm import LinearSVC
from sklearn import svm

# Question 4 Library
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

## Cross validation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn import metrics

# %% [markdown]
# # Question 1

# %% [markdown]
# Plot a histogram of the number of training documents for each of the 20 categories to check if they are evenly distributed.

# %%
newsgroups_train = fetch_20newsgroups(subset='train')

# %%
type(newsgroups_train.target)
news_target = newsgroups_train.target
plt.hist(news_target)
plt.xlabel('Categories')
plt.ylabel('Counts')
plt.xticks(list(range(20)))
plt.title('Question 1: Number of Documents for each categories')
plt.show()

# %% [markdown]
# # Question 2

# %% [markdown]
# Use the following specs to extract features from the textual data:
# • Use the “english” stopwords of the CountVectorizer
# • Exclude terms that are numbers (e.g. “123”, “-45”, “6.7” etc.)
# • Perform lemmatization with nltk.wordnet.WordNetLemmatizer and pos_tag
# • Use min_df=3
# Report the shape of the TF-IDF matrices of the train and test subsets respectively.

# %%
np.random.seed(42);
random.seed(42); # do I set the random here
categories = ['comp.graphics', 
              'comp.os.ms-windows.misc',
              'comp.sys.ibm.pc.hardware', 
              'comp.sys.mac.hardware', 
              'rec.autos', 
              'rec.motorcycles', 
              'rec.sport.baseball', 
              'rec.sport.hockey']

train_dataset = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=None)
test_dataset = fetch_20newsgroups(subset='test', categories=categories, shuffle=True, random_state=None)

# %%
# Customize analyzer
analyzer = CountVectorizer().build_analyzer();
# Lemmatizer
wnl = nltk.wordnet.WordNetLemmatizer()

def penn2morphy(penntag):
    """ Converts Penn Treebank tags to WordNet. """
    morphy_tag = {'NN':'n', 'JJ':'a',
                  'VB':'v', 'RB':'r'}
    try:
        return morphy_tag[penntag[:2]]
    except:
        return 'n'
    
def lemmatize_sent(list_word):
    return [wnl.lemmatize(word.lower(), pos=penn2morphy(tag)) for word, tag, in pos_tag(list_word)]

def stem_rmv_punc(doc):
    return (word for word in lemmatize_sent(analyzer(doc)) if not word.isdigit())
count_vect = CountVectorizer(stop_words='english', min_df=3, analyzer=stem_rmv_punc)

# %% [markdown]
# ### Training Part

# %%
tfidf_transformer = TfidfTransformer()
X_train_counts = count_vect.fit_transform(train_dataset.data)
X_train_tf_idf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tf_idf.shape
# Out:
# (4732, 16600)

# %% [markdown]
# ### Testing Part

# %%
X_test_counts = count_vect.transform(test_dataset.data)
X_test_tf_idf = tfidf_transformer.transform(X_test_counts)
X_test_tf_idf.shape
# Out:
# (3150, 16600)

# %% [markdown]
# # Question 3

# %% [markdown]
# Reduce the dimensionality of the data using the methods above
#
# • Apply LSI to the TF-IDF matrix corresponding to the 8 categories with k = 50; so each document is mapped to a 50-dimensional vector.
#
# • Also reduce dimensionality through NMF (k = 50) and compare with LSI:
# Which one is larger, the ∥X − WH∥ F 2 in NMF or the X − U k Σ k V T k F in LSI? Why is the case?

# %%
# NMF
## Train
model = NMF(n_components=50, init='random', random_state=0)
NMF_train_reduced = model.fit_transform(X_train_tf_idf)
## Test
NMF_test_reduced = model.transform(X_test_tf_idf)
print("NMF train shape: ", NMF_train_reduced.shape)
print("NMF test shape: ", NMF_test_reduced.shape)
# Out:
# NMF train shape:  (4732, 50)
# NMF test shape:  (3150, 50)

# %%
H_train = model.components_
NMF_train_val = np.sum(np.array(X_train_tf_idf - NMF_train_reduced.dot(H_train))**2)
NMF_test_val = np.sum(np.array(X_test_tf_idf - NMF_test_reduced.dot(H_train))**2)

# %%
print("||X-WH||^2_F Train: ", NMF_train_val)
print("||X-WH||^2_F Test: ", NMF_test_val)
# Out:
# ||X-WH||^2_F Train:  3940.5577667857333
# ||X-WH||^2_F Test:  2691.949309920702

# %%
# LSI
## Train
svd = TruncatedSVD(n_components=50, random_state=0)
LSI_train_reduced = svd.fit_transform(X_train_tf_idf)
## Test
LSI_test_reduced = svd.transform(X_test_tf_idf)
print("LSI train shape: ", LSI_train_reduced.shape)
print("LSI test shape: ", LSI_test_reduced.shape)
# Out:
# LSI train shape:  (4732, 50)
# LSI test shape:  (3150, 50)

# %%
H = svd.components_
## Train
LSI_train_val = np.sum(np.array(X_train_tf_idf - LSI_train_reduced.dot(H))**2)
## Test
LSI_test_val = np.sum(np.array(X_test_tf_idf - LSI_test_reduced.dot(H))**2)

# %%
print("||X - USigmaV^T||^2_F Train", LSI_train_val)
print("||X - USigmaV^T||^2_F Test", LSI_test_val)
# Out:
# ||X - USigmaV^T||^2_F Train 3895.601668902093
# ||X - USigmaV^T||^2_F Test 2676.5911826488655

# %% [markdown]
# # Question 4

# %%
def mergeToBinary(multiClassArray):
    res = np.copy(multiClassArray)
    for i in range(len(multiClassArray)):
        if multiClassArray[i] <= 3:
            res[i] = 0
        else:
            res[i] = 1
    return res

# %%
train_labels = mergeToBinary(train_dataset.target)
test_labels = mergeToBinary(test_dataset.target)

# %%
# %matplotlib inline
def plot_roc(fpr, tpr):
    fig, ax = plt.subplots()

    roc_auc = auc(fpr,tpr)

    ax.plot(fpr, tpr, lw=2, label= 'area under curve = %0.4f' % roc_auc)

    ax.grid(color='0.7', linestyle='--', linewidth=1)

    ax.set_xlim([-0.1, 1.1])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate',fontsize=15)
    ax.set_ylabel('True Positive Rate',fontsize=15)

    ax.legend(loc="lower right")

    for label in ax.get_xticklabels()+ax.get_yticklabels():
        label.set_fontsize(15)

def fit_predict_and_plot_roc(pipe, train_data, train_label, test_data, test_label):
    pipe.fit(train_data, train_label)
    # pipeline1.predict(twenty_test.data)

    if hasattr(pipe, 'decision_function'):
        prob_score = pipe.decision_function(test_data)
        fpr, tpr, _ = roc_curve(test_label, prob_score)
    else:
        prob_score = pipe.predict_proba(test_data)
        fpr, tpr, _ = roc_curve(test_label, prob_score[:,1])

    plot_roc(fpr, tpr)
#     return pipe

def confusionMatrixAndMetrics(ground_truth, predicts):
    conf_matrix = confusion_matrix(ground_truth, predicts)
    preci = precision_score(ground_truth, predicts)
    recall = recall_score(ground_truth, predicts)
    accur = accuracy_score(ground_truth, predicts)
    F1 = 2 / (1/recall + 1/preci)
    print("accuracy: ", accur)
    print("precision: ", preci)
    print("recall: ", recall)
    print("F1 score: ", F1)
    print ("confusion matrix: \n", conf_matrix)

# %%
hard_model = LinearSVC(loss='hinge', C=1000)
fit_predict_and_plot_roc(hard_model, LSI_train_reduced , train_labels, LSI_test_reduced, test_labels)
predicts = hard_model.fit(LSI_train_reduced, train_labels).predict(LSI_test_reduced)
confusionMatrixAndMetrics(test_labels, predicts)
# Out:
# accuracy:  0.9612698412698413
# precision:  0.9358669833729216
# recall:  0.9911949685534591
# F1 score:  0.9627367135003053
# confusion matrix:
#  [[1452  108]
#  [  14 1576]]

# %%
soft_model = LinearSVC(loss='hinge', C=0.0001)
fit_predict_and_plot_roc(soft_model, LSI_train_reduced , train_labels, LSI_test_reduced, test_labels)
predicts = soft_model.fit(LSI_train_reduced, train_labels).predict(LSI_test_reduced)
confusionMatrixAndMetrics(test_labels, predicts)
# Out:
# accuracy:  0.5053968253968254
# precision:  0.5050825921219823
# recall:  1.0
# F1 score:  0.671169269734065
# confusion matrix:
#  [[   2 1558]
#  [   0 1590]]

# %% [markdown]
# ## Cross Validation

# %%
cv = ShuffleSplit(n_splits=5, random_state=0, test_size=0.3)
best_score = -1
best_i = -1;
for i in [-3, -2, -1, 0, 1, 2, 3]:
    clf = LinearSVC(loss='hinge', C=10**i)
    scores = cross_val_score(clf, LSI_train_reduced, train_labels, cv=cv, scoring='accuracy')
    print("C: ", 10**i, " score: ", np.mean(scores))
    if np.mean(scores) > best_score:
        best_score = np.mean(scores)
        best_i = i
best_c = 10**best_i
print("Best C: ", best_c)

cv_model = LinearSVC(loss='hinge', C=best_c)
fit_predict_and_plot_roc(cv_model, LSI_train_reduced , train_labels, LSI_test_reduced, test_labels)
predicts = cv_model.fit(LSI_train_reduced, train_labels).predict(LSI_test_reduced)
confusionMatrixAndMetrics(test_labels, predicts)
# Out:
# C:  0.001  score:  0.6325352112676057
# C:  0.01  score:  0.6328169014084507
# C:  0.1  score:  0.9643661971830987
# C:  1  score:  0.9738028169014085
# C:  10  score:  0.9759154929577466
# C:  100  score:  0.975774647887324
# C:  1000  score:  0.9749295774647887
# Best C:  10
# accuracy:  0.9682539682539683
# precision:  0.9621588089330024
# recall:  0.9754716981132076
# F1 score:  0.9687695190505935
# confusion matrix:
#  [[1499   61]
#  [  39 1551]]

# %% [markdown]
# # Question 5

# %%
from sklearn.linear_model import LogisticRegression

# approximate logreq without regularization
logreg = LogisticRegression(random_state=0, C = 999999)
fit_predict_and_plot_roc(logreg, LSI_train_reduced , train_labels, LSI_test_reduced, test_labels)
predicts = logreg.fit(LSI_train_reduced, train_labels).predict(LSI_test_reduced)
confusionMatrixAndMetrics(test_labels, predicts)
# Out:
# accuracy:  0.9695238095238096
# precision:  0.9628252788104089
# recall:  0.9773584905660377
# F1 score:  0.9700374531835206
# confusion matrix:
#  [[1500   60]
#  [  36 1554]]

# %% [markdown]
# # Cross Validation for Logistic Regression

# %%
# L1 norm regularization
cv = ShuffleSplit(n_splits=5, random_state=0, test_size=0.3)
best_score = -1
best_i = -1;
for i in [-3, -2, -1, 0, 1, 2, 3]:
    clf = LogisticRegression(random_state = 0, penalty = "l1", C=10**i)
    scores = cross_val_score(clf, LSI_train_reduced, train_labels, cv=cv, scoring='accuracy')
    print("C: ", 10**i, " score: ", np.mean(scores))
    if np.mean(scores) > best_score:
        best_score = np.mean(scores)
        best_i = i
best_c = 10**best_i
print("Best C: ", best_c)
# Out:
# C:  0.001  score:  0.4954929577464789
# C:  0.01  score:  0.4954929577464789
# C:  0.1  score:  0.9474647887323944
# C:  1  score:  0.9701408450704225
# C:  10  score:  0.9774647887323942
# C:  100  score:  0.9770422535211267
# C:  1000  score:  0.9770422535211267
# Best C:  10

# %%
logreg = LogisticRegression(random_state=0, penalty = "l1", C = best_c)
fit_predict_and_plot_roc(logreg, LSI_train_reduced , train_labels, LSI_test_reduced, test_labels)
predicts = logreg.fit(LSI_train_reduced, train_labels).predict(LSI_test_reduced)
confusionMatrixAndMetrics(test_labels, predicts)
# Out:
# accuracy:  0.9682539682539683
# precision:  0.9604449938195303
# recall:  0.9773584905660377
# F1 score:  0.9688279301745637
# confusion matrix:
#  [[1496   64]
#  [  36 1554]]

# %%
# L2 norm regularization
cv = ShuffleSplit(n_splits=5, random_state=0, test_size=0.3)
best_score = -1
best_i = -1;
for i in [-3, -2, -1, 0, 1, 2, 3]:
    clf = LogisticRegression(random_state = 0, penalty = "l2", C=10**i)
    scores = cross_val_score(clf, LSI_train_reduced, train_labels, cv=cv, scoring='accuracy')
    print("C: ", 10**i, " score: ", np.mean(scores))
    if np.mean(scores) > best_score:
        best_score = np.mean(scores)
        best_i = i
best_c = 10**best_i
print("Best C: ", best_c)
# Out:
# C:  0.001  score:  0.6919718309859154
# C:  0.01  score:  0.9025352112676057
# C:  0.1  score:  0.9523943661971831
# C:  1  score:  0.9698591549295775
# C:  10  score:  0.9753521126760564
# C:  100  score:  0.9769014084507044
# C:  1000  score:  0.9771830985915495
# Best C:  1000

# %%
logreg = LogisticRegression(random_state=0, penalty = "l2", C = best_c)
fit_predict_and_plot_roc(logreg, LSI_train_reduced , train_labels, LSI_test_reduced, test_labels)
predicts = logreg.fit(LSI_train_reduced, train_labels).predict(LSI_test_reduced)
confusionMatrixAndMetrics(test_labels, predicts)
# Out:
# accuracy:  0.9685714285714285
# precision:  0.961609907120743
# recall:  0.9767295597484277
# F1 score:  0.9691107644305773
# confusion matrix:
#  [[1498   62]
#  [  37 1553]]

# %% [markdown]
# # Question 6

# %%
from sklearn.naive_bayes import GaussianNB

# %%
GNB = GaussianNB()
fit_predict_and_plot_roc(GNB, LSI_train_reduced , train_labels, LSI_test_reduced, test_labels)
predicts = GNB.fit(LSI_train_reduced, train_labels).predict(LSI_test_reduced)
confusionMatrixAndMetrics(test_labels, predicts)
# Out:
# accuracy:  0.926031746031746
# precision:  0.9026706231454006
# recall:  0.9566037735849057
# F1 score:  0.9288549618320611
# confusion matrix:
#  [[1396  164]
#  [  69 1521]]

# %% [markdown]
# # Question 7

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from tempfile import mkdtemp
from shutil import rmtree
from sklearn.externals.joblib import Memory
import pandas as pd

# %%
def dumb_stem(doc):
    return (word for word in doc)

cachedir = mkdtemp()
memory = Memory(cachedir=cachedir, verbose=10)

pipeline = Pipeline([
    ('vect', CountVectorizer(min_df=1, stop_words='english')),
    ('tfidf', TfidfTransformer()),
    ('reduce_dim', TruncatedSVD(random_state=0)),
    ('clf', GaussianNB()),
],
memory=memory
)

MIN_DF_OPTIONS = [3, 5]
ANALYZER_OPTIONS = [stem_rmv_punc, dumb_stem]
N_FEATURES_OPTIONS = [50]
C_OPTIONS = [1000]
LOG_REG_PENALTY_OPTIONS = ['l1', 'l2']
# REG_OPTIONS = ['l1', 'l2']
# REG_STRENGTH_OPTIONS = [0.1, 1, 10]

param_grid = [
    {
        'vect__min_df': MIN_DF_OPTIONS,
        'vect__analyzer': ANALYZER_OPTIONS,
        'reduce_dim': [TruncatedSVD(), NMF()],
        'reduce_dim__n_components': N_FEATURES_OPTIONS,
        'clf': [LinearSVC()],
        'clf__C': [100]
    },
    {
        'vect__min_df': MIN_DF_OPTIONS,
        'vect__analyzer': ANALYZER_OPTIONS,
        'reduce_dim': [TruncatedSVD(), NMF()],
        'reduce_dim__n_components': N_FEATURES_OPTIONS,
        'clf': [LogisticRegression()],
        'clf__penalty': ['l1'],
        'clf__C': [10]
    },
    {
        'vect__min_df': MIN_DF_OPTIONS,
        'vect__analyzer': ANALYZER_OPTIONS,
        'reduce_dim': [TruncatedSVD(), NMF()],
        'reduce_dim__n_components': N_FEATURES_OPTIONS,
        'clf': [LogisticRegression()],
        'clf__penalty': ['l2'],
        'clf__C': [1000]
    },
    {
        'vect__min_df': MIN_DF_OPTIONS,
        'vect__analyzer': ANALYZER_OPTIONS,
        'reduce_dim': [TruncatedSVD(), NMF()],
        'reduce_dim__n_components': N_FEATURES_OPTIONS,
        'clf': [GaussianNB()],
#         'clf__C': C_OPTIONS
    },
]
# reducer_labels = ['LinearSVC', 'NMF', 'KBest(chi2)']

grid = GridSearchCV(pipeline, cv=5, n_jobs=1, param_grid=param_grid, scoring='accuracy')
grid.fit(train_dataset.data, train_dataset.target)
# Out:
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: dcoleman@utxvms.cc.utexas.edu (Daniel M. Coleman)\n'
#   'Subject: Re: MathCad 4.0 swap file\n'
#   'Lines: 28\n'
#   'Nntp-Posting-Host: blonde.cc.utexas.edu\n'
#   'Organization: The University of Texas at Austin\n'
#   'Lines: 28\n'
#   '\n'
#   'In article <1993Apr20.175608.23949@ncar.ucar.edu>, '
#   'baseball@catch-the-fever.scd.ucar.edu (Gregg Walters) writes:\n'
#   '> I have 16MB of memory on my 386SX.  I have been running Windows\n'
#   '> without a swap file for several months.  Will Mathcad 4.0 be\n'
#   '> happy with this, or insist on a swap file?\n'
#   '\n'
#   'I just got Mathcad 4.0, and the manual is not clear on the matter.  On page '
#   '8:\n'
#   '\n'
#   '\t:\n'
#   '\t:\n'
#   '\n'
#   '* At lea...,
# array([1, ..., 2]), None)
# _______________________________________________fit_transform_one - 47.1s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3783x14444 sparse matrix of type '<class 'numpy.int64'>'
# 	with 430106 stored elements in Compressed Sparse Row format>,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3783x14444 sparse matrix of type '<class 'numpy.float64'>'
# 	with 430106 stored elements in Compressed Sparse Row format>,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.4s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# _______________________________________________fit_transform_one - 45.6s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3784x14105 sparse matrix of type '<class 'numpy.int64'>'
# 	with 424899 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3784x14105 sparse matrix of type '<class 'numpy.float64'>'
# 	with 424899 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# _______________________________________________fit_transform_one - 46.2s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3785x14508 sparse matrix of type '<class 'numpy.int64'>'
# 	with 429717 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3785x14508 sparse matrix of type '<class 'numpy.float64'>'
# 	with 429717 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.4s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# _______________________________________________fit_transform_one - 45.9s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3787x14099 sparse matrix of type '<class 'numpy.int64'>'
# 	with 428579 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3787x14099 sparse matrix of type '<class 'numpy.float64'>'
# 	with 428579 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 6]), None)
# _______________________________________________fit_transform_one - 45.4s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3789x14306 sparse matrix of type '<class 'numpy.int64'>'
# 	with 430998 stored elements in Compressed Sparse Row format>,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3789x14306 sparse matrix of type '<class 'numpy.float64'>'
# 	with 430998 stored elements in Compressed Sparse Row format>,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: dcoleman@utxvms.cc.utexas.edu (Daniel M. Coleman)\n'
#   'Subject: Re: MathCad 4.0 swap file\n'
#   'Lines: 28\n'
#   'Nntp-Posting-Host: blonde.cc.utexas.edu\n'
#   'Organization: The University of Texas at Austin\n'
#   'Lines: 28\n'
#   '\n'
#   'In article <1993Apr20.175608.23949@ncar.ucar.edu>, '
#   'baseball@catch-the-fever.scd.ucar.edu (Gregg Walters) writes:\n'
#   '> I have 16MB of memory on my 386SX.  I have been running Windows\n'
#   '> without a swap file for several months.  Will Mathcad 4.0 be\n'
#   '> happy with this, or insist on a swap file?\n'
#   '\n'
#   'I just got Mathcad 4.0, and the manual is not clear on the matter.  On page '
#   '8:\n'
#   '\n'
#   '\t:\n'
#   '\t:\n'
#   '\n'
#   '* At lea...,
# array([1, ..., 2]), None)
# _______________________________________________fit_transform_one - 46.8s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3783x9157 sparse matrix of type '<class 'numpy.int64'>'
# 	with 412283 stored elements in Compressed Sparse Row format>,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3783x9157 sparse matrix of type '<class 'numpy.float64'>'
# 	with 412283 stored elements in Compressed Sparse Row format>,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# _______________________________________________fit_transform_one - 47.1s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3784x9056 sparse matrix of type '<class 'numpy.int64'>'
# 	with 407838 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3784x9056 sparse matrix of type '<class 'numpy.float64'>'
# 	with 407838 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# _______________________________________________fit_transform_one - 46.0s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3785x9142 sparse matrix of type '<class 'numpy.int64'>'
# 	with 411668 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3785x9142 sparse matrix of type '<class 'numpy.float64'>'
# 	with 411668 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# _______________________________________________fit_transform_one - 45.6s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3787x9159 sparse matrix of type '<class 'numpy.int64'>'
# 	with 411837 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3787x9159 sparse matrix of type '<class 'numpy.float64'>'
# 	with 411837 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 6]), None)
# _______________________________________________fit_transform_one - 45.0s, 0.7min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3789x9263 sparse matrix of type '<class 'numpy.int64'>'
# 	with 413943 stored elements in Compressed Sparse Row format>,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3789x9263 sparse matrix of type '<class 'numpy.float64'>'
# 	with 413943 stored elements in Compressed Sparse Row format>,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: dcoleman@utxvms.cc.utexas.edu (Daniel M. Coleman)\n'
#   'Subject: Re: MathCad 4.0 swap file\n'
#   'Lines: 28\n'
#   'Nntp-Posting-Host: blonde.cc.utexas.edu\n'
#   'Organization: The University of Texas at Austin\n'
#   'Lines: 28\n'
#   '\n'
#   'In article <1993Apr20.175608.23949@ncar.ucar.edu>, '
#   'baseball@catch-the-fever.scd.ucar.edu (Gregg Walters) writes:\n'
#   '> I have 16MB of memory on my 386SX.  I have been running Windows\n'
#   '> without a swap file for several months.  Will Mathcad 4.0 be\n'
#   '> happy with this, or insist on a swap file?\n'
#   '\n'
#   'I just got Mathcad 4.0, and the manual is not clear on the matter.  On page '
#   '8:\n'
#   '\n'
#   '\t:\n'
#   '\t:\n'
#   '\n'
#   '* At lea...,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3783x101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250230 stored elements in Compressed Sparse Row format>,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3783x101 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250230 stored elements in Compressed Sparse Row format>,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3784x102 sparse matrix of type '<class 'numpy.int64'>'
# 	with 249697 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3784x102 sparse matrix of type '<class 'numpy.float64'>'
# 	with 249697 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3785x101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250311 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3785x101 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250311 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3787x101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250483 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3787x101 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250483 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 1.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3789x101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250500 stored elements in Compressed Sparse Row format>,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3789x101 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250500 stored elements in Compressed Sparse Row format>,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: dcoleman@utxvms.cc.utexas.edu (Daniel M. Coleman)\n'
#   'Subject: Re: MathCad 4.0 swap file\n'
#   'Lines: 28\n'
#   'Nntp-Posting-Host: blonde.cc.utexas.edu\n'
#   'Organization: The University of Texas at Austin\n'
#   'Lines: 28\n'
#   '\n'
#   'In article <1993Apr20.175608.23949@ncar.ucar.edu>, '
#   'baseball@catch-the-fever.scd.ucar.edu (Gregg Walters) writes:\n'
#   '> I have 16MB of memory on my 386SX.  I have been running Windows\n'
#   '> without a swap file for several months.  Will Mathcad 4.0 be\n'
#   '> happy with this, or insist on a swap file?\n'
#   '\n'
#   'I just got Mathcad 4.0, and the manual is not clear on the matter.  On page '
#   '8:\n'
#   '\n'
#   '\t:\n'
#   '\t:\n'
#   '\n'
#   '* At lea...,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3783x98 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250218 stored elements in Compressed Sparse Row format>,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3783x98 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250218 stored elements in Compressed Sparse Row format>,
# array([1, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3784x99 sparse matrix of type '<class 'numpy.int64'>'
# 	with 249686 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3784x99 sparse matrix of type '<class 'numpy.float64'>'
# 	with 249686 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3785x98 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250300 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3785x98 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250300 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3787x99 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250476 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3787x99 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250476 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 1.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3789x98 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250488 stored elements in Compressed Sparse Row format>,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3789x98 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250488 stored elements in Compressed Sparse Row format>,
# array([6, ..., 6]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/bd4900844dfcf2226e55f9a051d656f1
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/ef42979b42e64624b9dad115d1b8cb24
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=50, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0),
# <3783x14444 sparse matrix of type '<class 'numpy.float64'>'
# 	with 430106 stored elements in Compressed Sparse Row format>,
# array([1, ..., 2]), None)
# _______________________________________________fit_transform_one - 10.0s, 0.2min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/21f2d0a6a3b910417c949cd6f911d89d
# ...
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/5085224ffc337638e684fc804cd573a4
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/6570a7b614201a7a822e9a4866e42817
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/5e79991294115c2a8727787e36879c40
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/17bdde0a5b60dd978e21d2d5dba59a22
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/a8a68b4e1928b7a72bfb44ffc9811357
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/e328bee34835a252818e4b88d49b5073
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/6d4e136836762321251db6367f92c15b
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/ec1be565879022ebf2e46b4d2d58056f
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/7f082e89bfb71f81e25c98459656e8bd
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/3b354d484ab35096974afeb602593071
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/9b755c6c170697aaa049e33341a54365
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/35a7518fff6905c0db93d3a39edcae25
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/9f228e8391249b30b8be73ccbd3fb294
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/e980299b82a616e3605030289362544f
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/a97e3603bd00b07c134278767dfa5757
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/1d54c7f4725d26777021d8aa516c18f6
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/bb74a4fe6793828cd5cddda6e9ede81d
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.2s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/9f4a237504e92173fb2f0ce3e3694ff6
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/ea81379c82ae3411963e9618103810a2
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/42dbfa7153912701596b36549491229e
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/759a7dcd5e311be077ef146a063ee93b
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/2ef37aff59cca6f59fdf783dcb980030
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/862c4daaa8d1ac7b515c57beca3f7b1b
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/66a4661a54ae2548564b94a7663b69ad
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/a8f08d65959e17a67657e817350436d0
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/d4f1647ecfdb054428a15a26684d80e0
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/c0e7a96f7020e25dd5b20121b05ef69d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/43eda7ae83e284d9223dd5e224835ac3
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/81460414da9118a5dfc8f010e5cda949
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/8c7856282425a9e75a0c2969862f7a02
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/b001a2632e8174ed80ff595e25ac5809
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/387625743df6f0206a916e067e37afc8
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.2s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/5ff0fdd855146ee9f8eac40d15477a89
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/deab25b8007204eaf74c321098110cdb
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/9f5416e04ebe4054e12b9632ea2edde3
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/89155b0f9bf72d7f90a7b0052568e7bc
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/a0cc1934a0f4a50afc9de4371bf419dc
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/4b61e04869d627f36a917064f52fe18c
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.2s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/698e67a7dfc874a350174e79efb92795
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/c902c493ecec3e8463e8f273d8ddb1ea
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/e776fdc2c76822c5963e22e796a3487e
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/9222973334d1376aacd8c296d302c977
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/81a145f56d265f26d152f8bba2af38f8
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/684f85d70d6ec271ad5e11f8f93d6cb6
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/45347c45b2f7fb71ac201612681d3bb5
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'From: sac@asdi.saic.com (Steve A. Conroy x6172)\n'
#   'Subject: Re: Darrrrrrrrryl\n'
#   'Organization: SAIC\n'
#   'Lines: 33\n'
#   '\n'
#   'In article <mssC5KCru.5Ip@netcom.com>, mss@netcom.com (Mark Singer) '
#   'writes:\n'
#   '|> \n'
#   '|> \n'
#   '|> The media is beating the incident at Dodger Stadium on Wednesday to\n'
#   "|> death, but I haven't seen anything in rsb yet.\n"
#   '|> \n'
#   '|> Gerald Perry of the Cardinals pinch hit in the eighth inning with two\n'
#   '|> on and his club down by a run.  He stroked a line drive into the\n'
#   '|> right field corner.  The ball cleared the three-foot high fence and\n'
#   '|> went into the crowd.  Darryl, racing over from right center, got to\n'
#   '|> th...,
# array([6, ..., 2]), None)
# _______________________________________________fit_transform_one - 56.7s, 0.9min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <4732x16600 sparse matrix of type '<class 'numpy.int64'>'
# 	with 541291 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <4732x16600 sparse matrix of type '<class 'numpy.float64'>'
# 	with 541291 stored elements in Compressed Sparse Row format>,
# array([6, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.4s, 0.0min
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=Pipeline(memory=Memory(location=/var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib),
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, m... n_iter=5, random_state=0,
#        tol=0.0)), ('clf', GaussianNB(priors=None, var_smoothing=1e-09))]),
#        fit_params=None, iid='warn', n_jobs=1,
#        param_grid=[{'vect__min_df': [3, 5], 'vect__analyzer': [<function stem_rmv_punc at 0x11d3727b8>, <function dumb_stem at 0x1250aee18>], 'reduce_dim': [TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0), NMF(alpha=0.0, beta_loss='frobenius', init=None, l...rbose=0)], 'reduce_dim__n_components': [50], 'clf': [GaussianNB(priors=None, var_smoothing=1e-09)]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       49.523613      0.653261        11.166323        0.445486
# 1       49.004293      0.801553        11.824415        0.879522
# 2        5.395324      0.036847         0.311407        0.008315
# 3        5.384696      0.029471         0.317297        0.015706
# 4       15.250289      1.960924        11.249737        0.347329
# 5       11.150645      1.748919        11.427419        0.568630
# 6        6.663390      0.291122         0.939306        0.031179
# 7        6.499724      0.069784         0.909073        0.006931
# 8        1.001905      0.048179        11.112888        0.459392
# 9        0.993186      0.038196        11.547454        0.862811
# 10       6.335039      0.646355         0.315743        0.006828
# 11       6.534704      0.431874         0.314529        0.010519
# 12       0.681072      0.045354        11.386579        0.476767
# 13       0.625871      0.019889        11.181569        0.480552
# 14       2.793107      0.212821         0.919398        0.028161
# 15       2.755081      0.162058         0.911976        0.008653
# 16       0.743222      0.033167        11.119544        0.484282
# 17       0.630220      0.047287        11.423400        0.665507
# 18       0.546504      0.034666         0.309951        0.007065
# 19       0.562620      0.030260         0.312679        0.009492
# 20       0.622508      0.068812        11.165139        0.417966
# 21       0.601563      0.074439        11.236793        0.454881
# 22       0.477514      0.022779         0.914651        0.009373
# 23       0.502468      0.015868         0.913385        0.011820
# 24       0.419618      0.012760        11.153337        0.494183
# 25       0.447980      0.070294        11.145882        0.545976
# 26       0.200483      0.044470         0.318263        0.006617
# 27       0.145273      0.006907         0.316680        0.007724
# 28       0.519047      0.024144        11.144400        0.462782
# 29       0.411337      0.036431        11.127493        0.478193
# 30       0.170007      0.030503         0.914216        0.014765
# 31       0.187396      0.015793         0.927479        0.028313
#
#                                             param_clf param_clf__C  \
# 0   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 1   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 2   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 3   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 4   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 5   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 6   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 7   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 8   LogisticRegression(C=10, class_weight=None, du...           10
# 9   LogisticRegression(C=10, class_weight=None, du...           10
# 10  LogisticRegression(C=10, class_weight=None, du...           10
# 11  LogisticRegression(C=10, class_weight=None, du...           10
# 12  LogisticRegression(C=10, class_weight=None, du...           10
# 13  LogisticRegression(C=10, class_weight=None, du...           10
# 14  LogisticRegression(C=10, class_weight=None, du...           10
# 15  LogisticRegression(C=10, class_weight=None, du...           10
# 16  LogisticRegression(C=1000, class_weight=None, ...         1000
# 17  LogisticRegression(C=1000, class_weight=None, ...         1000
# 18  LogisticRegression(C=1000, class_weight=None, ...         1000
# 19  LogisticRegression(C=1000, class_weight=None, ...         1000
# 20  LogisticRegression(C=1000, class_weight=None, ...         1000
# 21  LogisticRegression(C=1000, class_weight=None, ...         1000
# 22  LogisticRegression(C=1000, class_weight=None, ...         1000
# 23  LogisticRegression(C=1000, class_weight=None, ...         1000
# 24       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 25       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 26       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 27       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 28       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 29       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 30       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 31       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
#
#                                      param_reduce_dim  \
# 0   TruncatedSVD(algorithm='randomized', n_compone...
# 1   TruncatedSVD(algorithm='randomized', n_compone...
# 2   TruncatedSVD(algorithm='randomized', n_compone...
# 3   TruncatedSVD(algorithm='randomized', n_compone...
# 4   NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 5   NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 6   NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 7   NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 8   TruncatedSVD(algorithm='randomized', n_compone...
# 9   TruncatedSVD(algorithm='randomized', n_compone...
# 10  TruncatedSVD(algorithm='randomized', n_compone...
# 11  TruncatedSVD(algorithm='randomized', n_compone...
# 12  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 13  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 14  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 15  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 16  TruncatedSVD(algorithm='randomized', n_compone...
# 17  TruncatedSVD(algorithm='randomized', n_compone...
# 18  TruncatedSVD(algorithm='randomized', n_compone...
# 19  TruncatedSVD(algorithm='randomized', n_compone...
# 20  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 21  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 22  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 23  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 24  TruncatedSVD(algorithm='randomized', n_compone...
# 25  TruncatedSVD(algorithm='randomized', n_compone...
# 26  TruncatedSVD(algorithm='randomized', n_compone...
# 27  TruncatedSVD(algorithm='randomized', n_compone...
# 28  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 29  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 30  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 31  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
#
#    param_reduce_dim__n_components                     param_vect__analyzer  \
# 0                              50  <function stem_rmv_punc at 0x11d3727b8>
# 1                              50  <function stem_rmv_punc at 0x11d3727b8>
# 2                              50      <function dumb_stem at 0x1250aee18>
# 3                              50      <function dumb_stem at 0x1250aee18>
# 4                              50  <function stem_rmv_punc at 0x11d3727b8>
# 5                              50  <function stem_rmv_punc at 0x11d3727b8>
# 6                              50      <function dumb_stem at 0x1250aee18>
# 7                              50      <function dumb_stem at 0x1250aee18>
# 8                              50  <function stem_rmv_punc at 0x11d3727b8>
# 9                              50  <function stem_rmv_punc at 0x11d3727b8>
# 10                             50      <function dumb_stem at 0x1250aee18>
# 11                             50      <function dumb_stem at 0x1250aee18>
# 12                             50  <function stem_rmv_punc at 0x11d3727b8>
# 13                             50  <function stem_rmv_punc at 0x11d3727b8>
# 14                             50      <function dumb_stem at 0x1250aee18>
# 15                             50      <function dumb_stem at 0x1250aee18>
# 16                             50  <function stem_rmv_punc at 0x11d3727b8>
# 17                             50  <function stem_rmv_punc at 0x11d3727b8>
# 18                             50      <function dumb_stem at 0x1250aee18>
# 19                             50      <function dumb_stem at 0x1250aee18>
# 20                             50  <function stem_rmv_punc at 0x11d3727b8>
# 21                             50  <function stem_rmv_punc at 0x11d3727b8>
# 22                             50      <function dumb_stem at 0x1250aee18>
# 23                             50      <function dumb_stem at 0x1250aee18>
# 24                             50  <function stem_rmv_punc at 0x11d3727b8>
# 25                             50  <function stem_rmv_punc at 0x11d3727b8>
# 26                             50      <function dumb_stem at 0x1250aee18>
# 27                             50      <function dumb_stem at 0x1250aee18>
# 28                             50  <function stem_rmv_punc at 0x11d3727b8>
# 29                             50  <function stem_rmv_punc at 0x11d3727b8>
# 30                             50      <function dumb_stem at 0x1250aee18>
# 31                             50      <function dumb_stem at 0x1250aee18>
#
#    param_vect__min_df       ...        mean_test_score std_test_score  \
# 0                   3       ...               0.849324       0.007954
# 1                   5       ...               0.846154       0.007786
# 2                   3       ...               0.421598       0.014094
# 3                   5       ...               0.422866       0.010624
# 4                   3       ...               0.802409       0.007517
# 5                   5       ...               0.801141       0.002687
# 6                   3       ...               0.416737       0.013848
# 7                   5       ...               0.422443       0.008506
# 8                   3       ...               0.850169       0.007778
# 9                   5       ...               0.848056       0.007988
# 10                  3       ...               0.429417       0.013376
# 11                  5       ...               0.430262       0.012951
# 12                  3       ...               0.802620       0.008264
# 13                  5       ...               0.799239       0.006691
# 14                  3       ...               0.415680       0.010673
# 15                  5       ...               0.421598       0.010637
# 16                  3       ...               0.849324       0.007460
# 17                  5       ...               0.845520       0.008535
# 18                  3       ...               0.432375       0.015631
# 19                  5       ...               0.431319       0.017346
# 20                  3       ...               0.808115       0.006434
# 21                  5       ...               0.805368       0.004686
# 22                  3       ...               0.418639       0.014101
# 23                  5       ...               0.422654       0.008902
# 24                  3       ...               0.723584       0.021602
# 25                  5       ...               0.723795       0.015969
# 26                  3       ...               0.281276       0.018474
# 27                  5       ...               0.281065       0.020367
# 28                  3       ...               0.683643       0.024117
# 29                  5       ...               0.688292       0.013647
# 30                  3       ...               0.250211       0.010628
# 31                  5       ...               0.257819       0.013261
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 0                 2            0.879989            0.865222
# 1                 5            0.868623            0.865751
# 2                24            0.454137            0.444503
# 3                21            0.439334            0.442918
# 4                10            0.819455            0.810518
# 5                11            0.804388            0.820296
# 6                27            0.439863            0.447146
# 7                23            0.441713            0.451374
# 8                 1            0.881047            0.866543
# 9                 4            0.872059            0.868658
# 10               20            0.464975            0.463266
# 11               19            0.464446            0.463266
# 12                9            0.815490            0.805497
# 13               12            0.805974            0.817918
# 14               28            0.443563            0.442389
# 15               24            0.440656            0.446353
# 16                2            0.881840            0.868393
# 17                6            0.872059            0.867072
# 18               17            0.464446            0.466438
# 19               18            0.466032            0.465381
# 20                7            0.824214            0.809989
# 21                8            0.812054            0.823996
# 22               26            0.445149            0.459038
# 23               22            0.447000            0.455338
# 24               14            0.741739            0.756871
# 25               13            0.741739            0.752114
# 26               29            0.291568            0.290962
# 27               30            0.289188            0.289905
# 28               16            0.714248            0.729387
# 29               15            0.699974            0.725159
# 30               32            0.256939            0.268235
# 31               31            0.256675            0.274313
#
#     split2_train_score  split3_train_score  split4_train_score  \
# 0             0.872127            0.869554            0.865664
# 1             0.870542            0.866385            0.863025
# 2             0.452312            0.472934            0.458168
# 3             0.450462            0.461315            0.443653
# 4             0.821136            0.812252            0.819477
# 5             0.822721            0.818590            0.819214
# 6             0.448877            0.453657            0.444444
# 7             0.446499            0.460523            0.442333
# 8             0.871598            0.873779            0.864608
# 9             0.872127            0.868233            0.864080
# 10            0.459181            0.471349            0.465294
# 11            0.459181            0.471085            0.464239
# 12            0.821136            0.811196            0.817366
# 13            0.822193            0.813309            0.817894
# 14            0.443857            0.454713            0.440486
# 15            0.441215            0.455770            0.441541
# 16            0.873184            0.874043            0.866456
# 17            0.873184            0.870082            0.865664
# 18            0.459709            0.473990            0.471628
# 19            0.461823            0.472670            0.468725
# 20            0.826948            0.816741            0.826603
# 21            0.826948            0.820438            0.822908
# 22            0.454161            0.458410            0.451834
# 23            0.448349            0.465276            0.450779
# 24            0.738441            0.744917            0.746635
# 25            0.752180            0.749406            0.745051
# 26            0.282959            0.312913            0.310108
# 27            0.282959            0.313177            0.311164
# 28            0.711757            0.694745            0.703352
# 29            0.714399            0.704780            0.719715
# 30            0.263937            0.292580            0.263394
# 31            0.268692            0.297069            0.264186
#
#     mean_train_score  std_train_score
# 0           0.870511         0.005382
# 1           0.866865         0.002562
# 2           0.456411         0.009379
# 3           0.447536         0.007773
# 4           0.816568         0.004310
# 5           0.817042         0.006482
# 6           0.446797         0.004585
# 7           0.448488         0.006941
# 8           0.871515         0.005804
# 9           0.869031         0.002968
# 10          0.464813         0.003927
# 11          0.464443         0.003827
# 12          0.814137         0.005377
# 13          0.815457         0.005512
# 14          0.445002         0.004998
# 15          0.445107         0.005708
# 16          0.872783         0.005349
# 17          0.869612         0.002864
# 18          0.467242         0.005099
# 19          0.466926         0.003618
# 20          0.820899         0.006579
# 21          0.821269         0.005059
# 22          0.453719         0.005050
# 23          0.453348         0.006605
# 24          0.745721         0.006239
# 25          0.748098         0.004104
# 26          0.297702         0.011711
# 27          0.297279         0.012413
# 28          0.710698         0.011588
# 29          0.712805         0.009295
# 30          0.269017         0.012322
# 31          0.272187         0.013715
#
# [32 rows x 27 columns]

# %%
train_dataset_removehf = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=None, remove = ("headers", "footers"))
# test_dataset_removehf = fetch_20newsgroups(subset='test', categories=categories, shuffle=True, random_state=None, remove =  (‘headers’, ‘footers’))
grid = GridSearchCV(pipeline, cv=5, n_jobs=1, param_grid=param_grid, scoring='accuracy')
grid.fit(train_dataset_removehf.data, train_dataset_removehf.target)

rmtree(cachedir)
# Out:
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'Sebastian C Sears, on the Tue, 13 Apr 1993 02:32:13 GMT wibbled:\n'
#   '\n'
#   ':                  ... Came around a right hand sweeper (going around\n'
#   ': \t45 mph) only to find a cager going around 30 mph, calmly driving \n'
#   ':       along, with no other traffic around, in *my* lane. Not crossing \n'
#   ':       the line, not swerving, fully and totally within the south-bound \n'
#   ':       lane of 9W (one lane each direction). \n'
#   '\n'
#   '\n'
#   "And I haven't even got there yet.  Must have been some other Brit...\n"
#   '--\n'
#   '\n'
#   'Nick (the English Biker)   DoD 1069   Concise Oxford   Left is Right\n'
#   '\n'
#   "M'Lud.",
#   '>\n'
#   '> What is a general rule of thumb for sobriety a...,
# array([5, ..., 2]), None)
# _______________________________________________fit_transform_one - 36.8s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3783x11736 sparse matrix of type '<class 'numpy.int64'>'
# 	with 336237 stored elements in Compressed Sparse Row format>,
# array([5, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3783x11736 sparse matrix of type '<class 'numpy.float64'>'
# 	with 336237 stored elements in Compressed Sparse Row format>,
# array([5, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# _______________________________________________fit_transform_one - 36.0s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3784x12200 sparse matrix of type '<class 'numpy.int64'>'
# 	with 338535 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3784x12200 sparse matrix of type '<class 'numpy.float64'>'
# 	with 338535 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# _______________________________________________fit_transform_one - 36.8s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3785x12051 sparse matrix of type '<class 'numpy.int64'>'
# 	with 340717 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3785x12051 sparse matrix of type '<class 'numpy.float64'>'
# 	with 340717 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# _______________________________________________fit_transform_one - 37.3s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3787x11861 sparse matrix of type '<class 'numpy.int64'>'
# 	with 339802 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3787x11861 sparse matrix of type '<class 'numpy.float64'>'
# 	with 339802 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 4]), None)
# _______________________________________________fit_transform_one - 35.3s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3789x11613 sparse matrix of type '<class 'numpy.int64'>'
# 	with 331066 stored elements in Compressed Sparse Row format>,
# array([4, ..., 4]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3789x11613 sparse matrix of type '<class 'numpy.float64'>'
# 	with 331066 stored elements in Compressed Sparse Row format>,
# array([4, ..., 4]), None)
# ________________________________________________fit_transform_one - 0.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'Sebastian C Sears, on the Tue, 13 Apr 1993 02:32:13 GMT wibbled:\n'
#   '\n'
#   ':                  ... Came around a right hand sweeper (going around\n'
#   ': \t45 mph) only to find a cager going around 30 mph, calmly driving \n'
#   ':       along, with no other traffic around, in *my* lane. Not crossing \n'
#   ':       the line, not swerving, fully and totally within the south-bound \n'
#   ':       lane of 9W (one lane each direction). \n'
#   '\n'
#   '\n'
#   "And I haven't even got there yet.  Must have been some other Brit...\n"
#   '--\n'
#   '\n'
#   'Nick (the English Biker)   DoD 1069   Concise Oxford   Left is Right\n'
#   '\n'
#   "M'Lud.",
#   '>\n'
#   '> What is a general rule of thumb for sobriety a...,
# array([5, ..., 2]), None)
# _______________________________________________fit_transform_one - 36.7s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3783x7578 sparse matrix of type '<class 'numpy.int64'>'
# 	with 322130 stored elements in Compressed Sparse Row format>,
# array([5, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3783x7578 sparse matrix of type '<class 'numpy.float64'>'
# 	with 322130 stored elements in Compressed Sparse Row format>,
# array([5, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# _______________________________________________fit_transform_one - 36.0s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3784x7632 sparse matrix of type '<class 'numpy.int64'>'
# 	with 323150 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3784x7632 sparse matrix of type '<class 'numpy.float64'>'
# 	with 323150 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# _______________________________________________fit_transform_one - 36.8s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3785x7606 sparse matrix of type '<class 'numpy.int64'>'
# 	with 325737 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3785x7606 sparse matrix of type '<class 'numpy.float64'>'
# 	with 325737 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# _______________________________________________fit_transform_one - 37.1s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3787x7667 sparse matrix of type '<class 'numpy.int64'>'
# 	with 325680 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3787x7667 sparse matrix of type '<class 'numpy.float64'>'
# 	with 325680 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 4]), None)
# _______________________________________________fit_transform_one - 37.8s, 0.6min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3789x7157 sparse matrix of type '<class 'numpy.int64'>'
# 	with 316069 stored elements in Compressed Sparse Row format>,
# array([4, ..., 4]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3789x7157 sparse matrix of type '<class 'numpy.float64'>'
# 	with 316069 stored elements in Compressed Sparse Row format>,
# array([4, ..., 4]), None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'Sebastian C Sears, on the Tue, 13 Apr 1993 02:32:13 GMT wibbled:\n'
#   '\n'
#   ':                  ... Came around a right hand sweeper (going around\n'
#   ': \t45 mph) only to find a cager going around 30 mph, calmly driving \n'
#   ':       along, with no other traffic around, in *my* lane. Not crossing \n'
#   ':       the line, not swerving, fully and totally within the south-bound \n'
#   ':       lane of 9W (one lane each direction). \n'
#   '\n'
#   '\n'
#   "And I haven't even got there yet.  Must have been some other Brit...\n"
#   '--\n'
#   '\n'
#   'Nick (the English Biker)   DoD 1069   Concise Oxford   Left is Right\n'
#   '\n'
#   "M'Lud.",
#   '>\n'
#   '> What is a general rule of thumb for sobriety a...,
# array([5, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3783x97 sparse matrix of type '<class 'numpy.int64'>'
# 	with 202400 stored elements in Compressed Sparse Row format>,
# array([5, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3783x97 sparse matrix of type '<class 'numpy.float64'>'
# 	with 202400 stored elements in Compressed Sparse Row format>,
# array([5, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.4s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3784x98 sparse matrix of type '<class 'numpy.int64'>'
# 	with 202670 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3784x98 sparse matrix of type '<class 'numpy.float64'>'
# 	with 202670 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3785x98 sparse matrix of type '<class 'numpy.int64'>'
# 	with 202677 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3785x98 sparse matrix of type '<class 'numpy.float64'>'
# 	with 202677 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.4s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3787x98 sparse matrix of type '<class 'numpy.int64'>'
# 	with 202674 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3787x98 sparse matrix of type '<class 'numpy.float64'>'
# 	with 202674 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 4]), None)
# ________________________________________________fit_transform_one - 1.4s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3789x97 sparse matrix of type '<class 'numpy.int64'>'
# 	with 202164 stored elements in Compressed Sparse Row format>,
# array([4, ..., 4]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3789x97 sparse matrix of type '<class 'numpy.float64'>'
# 	with 202164 stored elements in Compressed Sparse Row format>,
# array([4, ..., 4]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'Sebastian C Sears, on the Tue, 13 Apr 1993 02:32:13 GMT wibbled:\n'
#   '\n'
#   ':                  ... Came around a right hand sweeper (going around\n'
#   ': \t45 mph) only to find a cager going around 30 mph, calmly driving \n'
#   ':       along, with no other traffic around, in *my* lane. Not crossing \n'
#   ':       the line, not swerving, fully and totally within the south-bound \n'
#   ':       lane of 9W (one lane each direction). \n'
#   '\n'
#   '\n'
#   "And I haven't even got there yet.  Must have been some other Brit...\n"
#   '--\n'
#   '\n'
#   'Nick (the English Biker)   DoD 1069   Concise Oxford   Left is Right\n'
#   '\n'
#   "M'Lud.",
#   '>\n'
#   '> What is a general rule of thumb for sobriety a...,
# array([5, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.4s, 0.0min
# [Memory]1.6s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/8c5916b78e2c7a7b68b24053d5472ca4
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]1.6s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/33a7c3c80ff9221255b0ad00768d6e9e
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3784x97 sparse matrix of type '<class 'numpy.int64'>'
# 	with 202667 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3784x97 sparse matrix of type '<class 'numpy.float64'>'
# 	with 202667 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3785x97 sparse matrix of type '<class 'numpy.int64'>'
# 	with 202674 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3785x97 sparse matrix of type '<class 'numpy.float64'>'
# 	with 202674 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 1.4s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <3787x97 sparse matrix of type '<class 'numpy.int64'>'
# 	with 202671 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <3787x97 sparse matrix of type '<class 'numpy.float64'>'
# 	with 202671 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function dumb_stem at 0x1250aee18>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=5, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 4]), None)
# ________________________________________________fit_transform_one - 1.2s, 0.0min
# [Memory]1.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/d66bc7d5e57919e80c9dc3b03a46b646
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]1.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/a45e3a6bdc675f63f348a1697b76b3a2
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/029ce44b5dead13feaef830fb6321fb5
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/fc2586b5c5c94b7874aafdcba2d66d7a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=50, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0),
# <3783x11736 sparse matrix of type '<class 'numpy.float64'>'
# 	with 336237 stored elements in Compressed Sparse Row format>,
# array([5, ..., 2]), None)
# ________________________________________________fit_transform_one - 8.5s, 0.1min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/9e498b390137f212105feed47f0d6890
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/782e854b2637c9e6b993bae380a59e71
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=50, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001, verbose=0),
# <3784x12200 sparse matrix of type '<class 'numpy.float64'>'
# 	with 338535 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ...
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/32d6a8d0ffe039d98580bc2b1bfe9a44
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/5c8b788975ce91b25ca3c7e6d89da418
# ___________________________________fit_transform_one cache loaded - 0.2s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/84aea0b9c51dbf1c918a35516419327c
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/880b4805049065d4cc173bc4b7af382f
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/b10a0788b86ed93b86b8e068fee39f94
# ___________________________________fit_transform_one cache loaded - 0.2s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/12c570ed3b67f7630afafcb843fd5043
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/bd62f7e3de8d26225206bf737a675ecf
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/0c4702a47bb7ed6a535d4216713bc5aa
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/c8953bc8fe3407fd55fd608011741189
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/a14dc2ea55c97337087dc50b266bf173
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/53932f8678535fe21e167cbf404c718c
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/f39e3a588c7d98a2778cb9b2e820dfc0
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.4s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/d9bdd29192874d9e2c5e193379032af4
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/7aa392c05c6c76f78f0914396e8938e2
# ___________________________________fit_transform_one cache loaded - 0.3s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/b06781b3a9e84a370f85612f2a49e8b7
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/3ad7bdb2518d502b1f2a2890f73b5c3e
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/f2367f72d5429db2a5241dc54b3bf8f5
# ___________________________________fit_transform_one cache loaded - 0.2s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/77171dde3906a2acefabc87bb13291ed
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.3s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/a9db3c925bc2045de7b2019913b3997d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/e24f515dcacdca61c419c17cdf7fe2a7
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/8c5916b78e2c7a7b68b24053d5472ca4
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/d19a5e4219e596c120872ed4f776313c
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/1a28b9285b3eb8a514ea53c5d9569283
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/182886f162486d2871226876583212f1
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/31a60905478cd0c5c116568c3b8a80cf
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/732bd631cf8cd6b9f3e9713831f48fa1
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/a9010d1b624c95ac8e8540c084c1832d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/88111b5b832f3c34626197ca20bee8b1
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/bdc48f2a2a6414cf59e4cc6920b0411e
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/4eb8e3ae9e32ebf296620c24ad4926fd
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/6d6ff310cecf9a1c5670c5ea6060a8b3
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/a46470ed02b9553f15bb124c883d5c4f
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/d66bc7d5e57919e80c9dc3b03a46b646
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/e2ab3c7826cad97d17aaf209768ded08
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/f43149329be5b39685b770a230729f9c
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/8c5916b78e2c7a7b68b24053d5472ca4
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/d19a5e4219e596c120872ed4f776313c
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/711ac593b96be34bfd0fee24faa5aeac
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/759e83b966e78334b87a20c4ee463f76
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/8c95e73445cf70cd913b95ac8fe24ab4
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/c39b39943438bde8ba30f36b2543905a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/e81bf7ecac9906700e98eb37f8d8754b
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/2ba877d6d845e9551616854f36085bcf
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/b4a3e1945b3961a6105192fbb19710ec
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/0c7f0d11e22fdc71916a7755bef7158b
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/4a6968f0f1b1d43cfae717351359abb9
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/180f1d157099f85bd1e1b497f00f35fd
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/d66bc7d5e57919e80c9dc3b03a46b646
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/8d/lf3121w542n2kfb06dvp3ljm0000gn/T/tmpn5frp7ii/joblib/sklearn/pipeline/_fit_transform_one/e2ab3c7826cad97d17aaf209768ded08
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stem_rmv_punc at 0x11d3727b8>,
#         binary=False, decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=3, ngram_range=(1, 1), preprocessor=None,
#         stop_words='english', strip_accents=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None),
# [ 'In article <Apr21.053718.19765@engr.washington.edu>, '
#   'eliot@lanmola.engr.washington.edu (eliot) writes:\n'
#   '\n'
#   '>if the noise really bugs you, there is nothing else that you can do\n'
#   '>except to sell it and get a V6.\n'
#   '\n'
#   "Perhaps a nice used '88 Pontiac Fiero GT?  2.8 liters.\n"
#   '\n'
#   'Does anyone know if the motor mounts for the 2.8 and the twin-dual-cam 3.4\n'
#   'liter match?  The 3.4 is supposedly derived from the pushrod 3.1, which '
#   'was\n'
#   'a punched out 2.8 liter.  Should be a drop-in replacement, eh?  205 horses '
#   'in\n'
#   'a mid-engine the size of a Fiero?\n'
#   '\n'
#   "Larry Smith (smith@ctron.com)  No, I don't speak for Cabletron.  Need you "
#   'ask?...,
# array([4, ..., 2]), None)
# _______________________________________________fit_transform_one - 47.7s, 0.8min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True), <4732x13926 sparse matrix of type '<class 'numpy.int64'>'
# 	with 426184 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(algorithm='randomized', n_components=50, n_iter=5,
#        random_state=None, tol=0.0),
# <4732x13926 sparse matrix of type '<class 'numpy.float64'>'
# 	with 426184 stored elements in Compressed Sparse Row format>,
# array([4, ..., 2]), None)
# ________________________________________________fit_transform_one - 0.4s, 0.0min

# %%
pd.DataFrame(grid.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       39.775156      0.741421         8.988954        0.750386
# 1       39.741396      0.569586         9.058706        0.874013
# 2        5.919895      0.317143         0.280441        0.052456
# 3        5.648725      0.207340         0.250241        0.022968
# 4       13.004032      1.550663         9.186555        0.721536
# 5       10.416408      1.013940         9.215305        0.794270
# 6        6.351019      0.052877         0.818155        0.017311
# 7        5.268100      1.431604         0.822520        0.032987
# 8        0.785160      0.050696         8.996995        0.666143
# 9        0.713665      0.008624         8.982647        0.742182
# 10       6.530972      0.315544         0.257059        0.039038
# 11       6.926161      0.414918         0.252638        0.025902
# 12       0.598825      0.046271         9.107640        0.735039
# 13       0.532983      0.019884         9.095804        0.733268
# 14       2.934427      0.225683         0.826446        0.042499
# 15       2.897642      0.299394         0.860947        0.056872
# 16       0.754763      0.042629         9.321219        0.750589
# 17       0.678166      0.024946         9.267246        0.698024
# 18       0.475186      0.029362         0.248874        0.025247
# 19       0.418075      0.031423         0.242778        0.021564
# 20       0.611103      0.044085         9.220440        0.704530
# 21       0.543087      0.042692         9.717176        0.804561
# 22       0.538688      0.027426         0.880381        0.023377
# 23       0.504418      0.032721         0.874327        0.027678
# 24       0.471892      0.036605        10.702239        0.978266
# 25       0.356227      0.022672         9.418620        0.958580
# 26       0.129400      0.009933         0.247725        0.020169
# 27       0.106272      0.024415         0.246298        0.021139
# 28       0.421853      0.036821         9.012354        0.645230
# 29       0.403214      0.024100         9.740573        0.851179
# 30       0.125749      0.012805         0.815030        0.023548
# 31       0.129059      0.023726         0.822375        0.026615
#
#                                             param_clf param_clf__C  \
# 0   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 1   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 2   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 3   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 4   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 5   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 6   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 7   LinearSVC(C=100, class_weight=None, dual=True,...          100
# 8   LogisticRegression(C=10, class_weight=None, du...           10
# 9   LogisticRegression(C=10, class_weight=None, du...           10
# 10  LogisticRegression(C=10, class_weight=None, du...           10
# 11  LogisticRegression(C=10, class_weight=None, du...           10
# 12  LogisticRegression(C=10, class_weight=None, du...           10
# 13  LogisticRegression(C=10, class_weight=None, du...           10
# 14  LogisticRegression(C=10, class_weight=None, du...           10
# 15  LogisticRegression(C=10, class_weight=None, du...           10
# 16  LogisticRegression(C=1000, class_weight=None, ...         1000
# 17  LogisticRegression(C=1000, class_weight=None, ...         1000
# 18  LogisticRegression(C=1000, class_weight=None, ...         1000
# 19  LogisticRegression(C=1000, class_weight=None, ...         1000
# 20  LogisticRegression(C=1000, class_weight=None, ...         1000
# 21  LogisticRegression(C=1000, class_weight=None, ...         1000
# 22  LogisticRegression(C=1000, class_weight=None, ...         1000
# 23  LogisticRegression(C=1000, class_weight=None, ...         1000
# 24       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 25       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 26       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 27       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 28       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 29       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 30       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
# 31       GaussianNB(priors=None, var_smoothing=1e-09)          NaN
#
#                                      param_reduce_dim  \
# 0   TruncatedSVD(algorithm='randomized', n_compone...
# 1   TruncatedSVD(algorithm='randomized', n_compone...
# 2   TruncatedSVD(algorithm='randomized', n_compone...
# 3   TruncatedSVD(algorithm='randomized', n_compone...
# 4   NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 5   NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 6   NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 7   NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 8   TruncatedSVD(algorithm='randomized', n_compone...
# 9   TruncatedSVD(algorithm='randomized', n_compone...
# 10  TruncatedSVD(algorithm='randomized', n_compone...
# 11  TruncatedSVD(algorithm='randomized', n_compone...
# 12  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 13  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 14  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 15  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 16  TruncatedSVD(algorithm='randomized', n_compone...
# 17  TruncatedSVD(algorithm='randomized', n_compone...
# 18  TruncatedSVD(algorithm='randomized', n_compone...
# 19  TruncatedSVD(algorithm='randomized', n_compone...
# 20  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 21  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 22  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 23  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 24  TruncatedSVD(algorithm='randomized', n_compone...
# 25  TruncatedSVD(algorithm='randomized', n_compone...
# 26  TruncatedSVD(algorithm='randomized', n_compone...
# 27  TruncatedSVD(algorithm='randomized', n_compone...
# 28  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 29  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 30  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 31  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
#
#    param_reduce_dim__n_components                     param_vect__analyzer  \
# 0                              50  <function stem_rmv_punc at 0x11d3727b8>
# 1                              50  <function stem_rmv_punc at 0x11d3727b8>
# 2                              50      <function dumb_stem at 0x1250aee18>
# 3                              50      <function dumb_stem at 0x1250aee18>
# 4                              50  <function stem_rmv_punc at 0x11d3727b8>
# 5                              50  <function stem_rmv_punc at 0x11d3727b8>
# 6                              50      <function dumb_stem at 0x1250aee18>
# 7                              50      <function dumb_stem at 0x1250aee18>
# 8                              50  <function stem_rmv_punc at 0x11d3727b8>
# 9                              50  <function stem_rmv_punc at 0x11d3727b8>
# 10                             50      <function dumb_stem at 0x1250aee18>
# 11                             50      <function dumb_stem at 0x1250aee18>
# 12                             50  <function stem_rmv_punc at 0x11d3727b8>
# 13                             50  <function stem_rmv_punc at 0x11d3727b8>
# 14                             50      <function dumb_stem at 0x1250aee18>
# 15                             50      <function dumb_stem at 0x1250aee18>
# 16                             50  <function stem_rmv_punc at 0x11d3727b8>
# 17                             50  <function stem_rmv_punc at 0x11d3727b8>
# 18                             50      <function dumb_stem at 0x1250aee18>
# 19                             50      <function dumb_stem at 0x1250aee18>
# 20                             50  <function stem_rmv_punc at 0x11d3727b8>
# 21                             50  <function stem_rmv_punc at 0x11d3727b8>
# 22                             50      <function dumb_stem at 0x1250aee18>
# 23                             50      <function dumb_stem at 0x1250aee18>
# 24                             50  <function stem_rmv_punc at 0x11d3727b8>
# 25                             50  <function stem_rmv_punc at 0x11d3727b8>
# 26                             50      <function dumb_stem at 0x1250aee18>
# 27                             50      <function dumb_stem at 0x1250aee18>
# 28                             50  <function stem_rmv_punc at 0x11d3727b8>
# 29                             50  <function stem_rmv_punc at 0x11d3727b8>
# 30                             50      <function dumb_stem at 0x1250aee18>
# 31                             50      <function dumb_stem at 0x1250aee18>
#
#    param_vect__min_df       ...        mean_test_score std_test_score  \
# 0                   3       ...               0.811708       0.003430
# 1                   5       ...               0.805790       0.009827
# 2                   3       ...               0.416526       0.017791
# 3                   5       ...               0.420118       0.016205
# 4                   3       ...               0.774091       0.003257
# 5                   5       ...               0.773035       0.007678
# 6                   3       ...               0.412088       0.016923
# 7                   5       ...               0.420330       0.014659
# 8                   3       ...               0.808326       0.008348
# 9                   5       ...               0.806213       0.010668
# 10                  3       ...               0.427303       0.017525
# 11                  5       ...               0.427937       0.015703
# 12                  3       ...               0.774091       0.008396
# 13                  5       ...               0.773880       0.006648
# 14                  3       ...               0.412933       0.013775
# 15                  5       ...               0.416103       0.012406
# 16                  3       ...               0.809594       0.007008
# 17                  5       ...               0.804945       0.012418
# 18                  3       ...               0.428783       0.016635
# 19                  5       ...               0.430896       0.016205
# 20                  3       ...               0.778318       0.008482
# 21                  5       ...               0.774514       0.008366
# 22                  3       ...               0.413567       0.015431
# 23                  5       ...               0.416737       0.015585
# 24                  3       ...               0.679839       0.015387
# 25                  5       ...               0.696746       0.008652
# 26                  3       ...               0.247675       0.012002
# 27                  5       ...               0.249155       0.011595
# 28                  3       ...               0.674345       0.012080
# 29                  5       ...               0.671598       0.015562
# 30                  3       ...               0.246196       0.015930
# 31                  5       ...               0.246196       0.022191
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 0                 1            0.813640            0.829545
# 1                 5            0.819984            0.827167
# 2                24            0.455459            0.465381
# 3                22            0.469469            0.457188
# 4                 9            0.770288            0.786469
# 5                12            0.773989            0.785941
# 6                28            0.454666            0.448732
# 7                21            0.452287            0.449789
# 8                 3            0.817076            0.833245
# 9                 4            0.821835            0.834567
# 10               20            0.474227            0.472516
# 11               19            0.474227            0.467230
# 12                9            0.768173            0.787262
# 13               11            0.774518            0.788319
# 14               27            0.452022            0.442918
# 15               25            0.452287            0.445560
# 16                2            0.820513            0.832717
# 17                6            0.823156            0.835888
# 18               18            0.474227            0.471195
# 19               17            0.474227            0.468552
# 20                7            0.774782            0.792812
# 21                8            0.777425            0.791490
# 22               26            0.452815            0.446617
# 23               23            0.452815            0.450846
# 24               14            0.704732            0.713266
# 25               13            0.713719            0.715645
# 26               30            0.277557            0.271934
# 27               29            0.277557            0.271934
# 28               15            0.695480            0.684989
# 29               16            0.692308            0.697939
# 30               31            0.264869            0.284619
# 31               31            0.264869            0.276956
#
#     split2_train_score  split3_train_score  split4_train_score  \
# 0             0.823514            0.827568            0.826075
# 1             0.819022            0.822287            0.824756
# 2             0.453633            0.439398            0.446820
# 3             0.443593            0.463692            0.450515
# 4             0.794980            0.789807            0.790446
# 5             0.793923            0.787959            0.786223
# 6             0.452048            0.450224            0.463447
# 7             0.448613            0.460787            0.462127
# 8             0.827741            0.829680            0.825284
# 9             0.822193            0.824399            0.830298
# 10            0.466050            0.469501            0.464239
# 11            0.464201            0.470821            0.464239
# 12            0.797886            0.791656            0.789918
# 13            0.794188            0.788751            0.785959
# 14            0.438573            0.445471            0.457377
# 15            0.440687            0.454978            0.457377
# 16            0.826684            0.831001            0.828979
# 17            0.824306            0.829152            0.832146
# 18            0.466050            0.473726            0.465030
# 19            0.463937            0.473990            0.465030
# 20            0.798415            0.795881            0.794669
# 21            0.793659            0.791128            0.792821
# 22            0.449934            0.458410            0.457641
# 23            0.448877            0.459731            0.457377
# 24            0.715984            0.715870            0.724466
# 25            0.724439            0.723792            0.724202
# 26            0.270542            0.283866            0.290842
# 27            0.266314            0.286242            0.290842
# 28            0.713078            0.701083            0.699393
# 29            0.701717            0.688672            0.689892
# 30            0.283752            0.281489            0.255740
# 31            0.280581            0.289939            0.255740
#
#     mean_train_score  std_train_score
# 0           0.824069         0.005574
# 1           0.822643         0.003008
# 2           0.452138         0.008709
# 3           0.456891         0.009187
# 4           0.786398         0.008499
# 5           0.785607         0.006483
# 6           0.453823         0.005203
# 7           0.454720         0.005643
# 8           0.826605         0.005429
# 9           0.826658         0.004982
# 10          0.469306         0.003764
# 11          0.468144         0.003894
# 12          0.786979         0.010032
# 13          0.786347         0.006500
# 14          0.447272         0.006671
# 15          0.450178         0.006176
# 16          0.827979         0.004243
# 17          0.828930         0.004765
# 18          0.470046         0.003833
# 19          0.469147         0.004329
# 20          0.791312         0.008463
# 21          0.789305         0.006009
# 22          0.453083         0.004493
# 23          0.453929         0.004045
# 24          0.714864         0.006319
# 25          0.720359         0.004680
# 26          0.278948         0.007582
# 27          0.278578         0.008997
# 28          0.698805         0.009068
# 29          0.694105         0.004963
# 30          0.274094         0.011668
# 31          0.273617         0.012018
#
# [32 rows x 27 columns]

# %% [markdown]
# # Question 8

# %%
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier

# %%
categories = ["comp.sys.ibm.pc.hardware", 
              "comp.sys.mac.hardware",
              "misc.forsale", 
              "soc.religion.christian"]

new_train_dataset = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=None)
new_test_dataset = fetch_20newsgroups(subset='test', categories=categories, shuffle=True, random_state=None)

def confusionMatrixAndMetrics_multi(ground_truth, predicts):
    conf_matrix = confusion_matrix(ground_truth, predicts)
    preci = precision_score(ground_truth, predicts, average = "weighted")
    recall = recall_score(ground_truth, predicts, average = "weighted")
    accur = accuracy_score(ground_truth, predicts)
    F1 = 2 / (1/recall + 1/preci)
    print("accuracy: ", accur)
    print("precision: ", preci)
    print("recall: ", recall)
    print("F1 score: ", F1)
    print ("confusion matrix: \n", conf_matrix)

def multi_clf_pipeline(model, train_dataset, test_dataset):
    print(model)
    pipeline = Pipeline([
        ('vect', CountVectorizer(min_df=2, stop_words='english', analyzer = stem_rmv_punc)),
        ('tfidf', TfidfTransformer()),
        ('reduce_dim', TruncatedSVD(random_state=0, n_components = 50)),
        ('clf', model),
        ]
    )
    pipeline.fit(train_dataset.data, train_dataset.target)
    predicts = pipeline.predict(test_dataset.data)
    confusionMatrixAndMetrics_multi(test_dataset.target, predicts)
    

multi_clf_pipeline(OneVsOneClassifier(LinearSVC(C=100, random_state=42)), new_train_dataset, new_test_dataset)
multi_clf_pipeline(OneVsRestClassifier(LinearSVC(C=100, random_state=42)), new_train_dataset, new_test_dataset)
multi_clf_pipeline(OneVsOneClassifier(GaussianNB()), new_train_dataset, new_test_dataset)
multi_clf_pipeline(OneVsRestClassifier(GaussianNB()), new_train_dataset, new_test_dataset)
# Out:
# OneVsOneClassifier(estimator=LinearSVC(C=100, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=42, tol=0.0001,
#      verbose=0),
#           n_jobs=None)
# accuracy:  0.886261980830671
# precision:  0.8868278628957301
# recall:  0.886261980830671
# F1 score:  0.8865448315624996
# confusion matrix:
#  [[317  54  19   2]
#  [ 34 328  23   0]
#  [ 18  16 353   3]
#  [  1   3   5 389]]
# OneVsRestClassifier(estimator=LinearSVC(C=100, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=42, tol=0.0001,
#      verbose=0),
#           n_jobs=None)
# accuracy:  0.8849840255591054
# precision:  0.8851532073417058
# recall:  0.8849840255591054
# F1 score:  0.8850686083655873
# confusion matrix:
#  [[309  59  21   3]
#  [ 35 326  24   0]
#  [ 17  14 358   1]
#  [  3   1   2 392]]
# OneVsOneClassifier(estimator=GaussianNB(priors=None, var_smoothing=1e-09),
#           n_jobs=None)
# accuracy:  0.7175718849840256
# precision:  0.7188621760149871
# recall:  0.7175718849840256
# F1 score:  0.7182164509911984
# confusion matrix:
#  [[287  32  64   9]
#  [149 131  71  34]
#  [ 36  26 324   4]
#  [  1   0  16 381]]
# OneVsRestClassifier(estimator=GaussianNB(priors=None, var_smoothing=1e-09),
#           n_jobs=None)
# accuracy:  0.7079872204472843
# precision:  0.7067368461880411
# recall:  0.7079872204472843
# F1 score:  0.707361480759102
# confusion matrix:
#  [[274  32  74  12]
#  [134 130  86  35]
#  [ 34  30 320   6]
#  [  0   0  14 384]]
